# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv('flood_risk_dataset_india.csv')
print('files imported successfully')
# Out:
# files imported successfully

# %%
df
# Out:
#         Latitude  Longitude  Rainfall (mm)  Temperature (°C)  Humidity (%)  \
# 0      18.861663  78.835584     218.999493         34.144337     43.912963
# 1      35.570715  77.654451      55.353599         28.778774     27.585422
# 2      29.227824  73.108463     103.991908         43.934956     30.108738
# 3      25.361096  85.610733     198.984191         21.569354     34.453690
# 4      12.524541  81.822101     144.626803         32.635692     36.292267
# ...          ...        ...            ...               ...           ...
# 9998   19.527152  80.856280     120.301453         28.029593     61.680873
# 9999   14.297072  72.995680      77.219394         29.622711     88.936537
# 10000   9.311591  83.276298     273.864524         32.369090     55.264638
# 10001  35.454530  76.807256       5.836759         23.087083     79.919607
# 10002  21.662200  70.595955      47.477868         31.774465     64.771080
#
# ...

# %%
#This codes checks the existing data types in the dataset

df.dtypes
# Out:
# Latitude                  float64
# Longitude                 float64
# Rainfall (mm)             float64
# Temperature (°C)          float64
# Humidity (%)              float64
# River Discharge (m³/s)    float64
# Water Level (m)           float64
# Elevation (m)             float64
# Land Cover                 object
# Soil Type                  object
# Population Density        float64
# Infrastructure            float64
# Historical Floods         float64
# Flood Occurred              int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Latitude                  0
# Longitude                 0
# Rainfall (mm)             0
# Temperature (°C)          0
# Humidity (%)              0
# River Discharge (m³/s)    0
# Water Level (m)           1
# Elevation (m)             0
# Land Cover                1
# Soil Type                 0
# Population Density        0
# Infrastructure            1
# Historical Floods         1
# Flood Occurred            0
# dtype: int64

# %%
df.shape
# Out:
# (10003, 14)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 9998     False
# 9999     False
# 10000     True
# 10001     True
# 10002     True
# Length: 10003, dtype: bool

# %%
df.describe()
# Out:
#            Latitude     Longitude  Rainfall (mm)  Temperature (°C)  \
# count  10003.000000  10003.000000   10003.000000      10003.000000
# mean      22.330571     82.629645     150.002835         29.961136
# std        8.342073      8.389351      86.046324          8.668862
# min        8.000337     68.004575       0.014437         15.000166
# 25%       15.142975     75.363831      76.106994         22.406786
# 50%       22.283134     82.670152     150.619375         30.005920
# 75%       29.463149     89.935737     223.409840         37.411713
# max       36.991813     96.997820     299.970293         44.993681
#
#        Humidity (%)  River Discharge (m³/s)  Water Level (m)  Elevation (m)  \
# count  10003.000000            10003.000000     10002.000000   10003.000000
# mean      59.751175             2515.485736         5.018023    4417.774758
# std       23.140240             1441.564518         2.876749    2530.430097
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 9998     False
# 9999     False
# 10000     True
# 10001     True
# 10002     True
# Length: 10003, dtype: bool

# %%
for col in df.columns:
    print(f"\n--{col}--")
    print(df[col].value_counts(dropna=False))
# Out:
# --Latitude--
# Latitude
# 35.454530    2
# 9.311591     2
# 21.662200    2
# 33.241613    1
# 24.188721    1
#             ..
# 26.393327    1
# 18.263264    1
# 25.496441    1
# 17.048038    1
# 34.384886    1
# Name: count, Length: 10000, dtype: int64
#
# --Longitude--
# Longitude
# 76.807256    2
# 83.276298    2
# 70.595955    2
# 77.847532    1
# 93.971290    1
#             ..
# 80.820408    1
# 93.808844    1
# 81.558668    1
# 92.641678    1
# 77.488169    1
# Name: count, Length: 10000, dtype: int64
#
# --Rainfall (mm)--
# Rainfall (mm)
# 5.836759      2
# 273.864524    2
# 47.477868     2
# 46.377270     1
# 182.312450    1
#              ..
# 188.660279    1
# 66.947319     1
# 116.361680    1
# 257.001628    1
# 221.671773    1
# Name: count, Length: 10000, dtype: int64
#
# --Temperature (°C)--
# Temperature (°C)
# 23.087083    2
# 32.369090    2
# 31.774465    2
# 15.442249    1
# 38.306395    1
#             ..
# 16.193376    1
# 32.078515    1
# 18.159103    1
# ...

# %% [markdown]
# Observation:
#
# - The columns has the right data types
# - This dataset contains missing values on 'Water Level', 'Land Cover', 'Infrastructure', and 'Historical Floods'
# - - There are three duplicate rows in the dataset
